# %% [markdown]
# <a href="https://colab.research.google.com/github/Poornima-Devi/Image-Read-KNN-Gradient-Descent/blob/master/image_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/Poornima-Devi/Image-Read-KNN-Gradient-Descent.git
# Out:
# Cloning into 'Image-Read-KNN-Gradient-Descent'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 808 (delta 2), reused 0 (delta 0), pack-reused 778
# Receiving objects: 100% (808/808), 16.52 MiB | 18.82 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
image = cv2.imread("Image-Read-KNN-Gradient-Descent/ML.jpg")
h=image.shape[0]
w=image.shape[1]
c=image.shape[2]

print(h,w,c)
# Out:
# 189 267 3

# %%
(b,g,r) = image[10,20]
print(b,g,r)
# Out:
# 85 58 2

# %%
plt.imshow(image)
